# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing data

# %%
dataset = pd.read_excel("C:/Users/ashuj/OneDrive/Desktop/Mobile Sales Data.xlsx")

# %%
dataset
# Out:
#       Transaction ID  Day  Month  Year  Day Name    Brand  Units Sold  \
# 0                  1    9     10  2021       Sat   Xiaomi           6
# 1                  2    9     10  2021  Saturday     Vivo           6
# 2                  3    9     10  2021  Saturday     Vivo           8
# 3                  4   10     10  2021    Sunday   Xiaomi           5
# 4                  5   10     10  2021    Sunday  OnePlus           3
# ...              ...  ...    ...   ...       ...      ...         ...
# 3830            3831    7     10  2024    Monday  OnePlus           9
# 3831            3832    8     10  2024   Tuesday   Xiaomi           8
# 3832            3833    8     10  2024   Tuesday  OnePlus           7
# 3833            3834    8     10  2024   Tuesday  OnePlus           4
# 3834            3835    8     10  2024   Tuesday  Samsung           1
#
#       Price Per Unit     Customer Name  Customer Age       City  \
# ...

# %% [markdown]
# # Showing data of starting 10 rows

# %%
dataset.head(10)
# Out:
#    Transaction ID  Day  Month  Year  Day Name    Brand  Units Sold  \
# 0               1    9     10  2021       Sat   Xiaomi           6
# 1               2    9     10  2021  Saturday     Vivo           6
# 2               3    9     10  2021  Saturday     Vivo           8
# 3               4   10     10  2021    Sunday   Xiaomi           5
# 4               5   10     10  2021    Sunday  OnePlus           3
# 5               6   10     10  2021    Sunday  Samsung           3
# 6               7   10     10  2021       Sun  OnePlus           6
# 7               8   11     10  2021    Monday    Apple           2
# 8               9   11     10  2021       Mon     Vivo           6
# 9              10   11     10  2021    Monday  Samsung           6
#
#    Price Per Unit     Customer Name  Customer Age       City Payment Method  \
# 0        10174.70      Lalita Ahuja            38   Ludhiana            UPI
# ...

# %% [markdown]
# # Finding Mean of the Customer Age from the dataset

# %%
dataset["Customer Age"].mean()
# Out:
# 38.09830508474576

# %%
me = np.mean(dataset["Customer Age"])
me
# Out:
# 38.09830508474576

# %% [markdown]
# # Finding Median of the Customer Age column from the dataset

# %%
md = np.median(dataset["Customer Age"])
md
# Out:
# 38.0

# %% [markdown]
# # Finding Mode of the Customer Age column from the dataset

# %%
mo =dataset["Customer Age"].mode()[0]
mo
# Out:
# 27

# %% [markdown]
# # Count the Customer Age in the dataset

# %%
dataset["Customer Age"].value_counts().head(5)
# Out:
# Customer Age
# 27    111
# 30    108
# 32    105
# 36    105
# 26    103
# Name: count, dtype: int64

# %% [markdown]
# # Checking the null value are present or not in the dataset

# %%
dataset.isnull().sum()
# Out:
# Transaction ID      0
# Day                 0
# Month               0
# Year                0
# Day Name            0
# Brand               0
# Units Sold          0
# Price Per Unit      0
# Customer Name       0
# Customer Age        0
# City                0
# Payment Method      0
# Customer Ratings    0
# Mobile Model        0
# dtype: int64

# %% [markdown]
# # Plotting the graph using Seaborn of the Mean, Median and Mode of the dataset

# %%
sns.histplot(x="Customer Age",data=dataset,bins=[i for i in range (0,61,10)])
plt.plot([me for i in range (0,1000)],[i for i in range (0,1000)],c="yellow",label="mean")
plt.plot([md for i in range (0,1000)],[i for i in range (0,1000)],c="blue",label="median")
plt.plot([mo for i in range (0,1000)],[i for i in range (0,1000)],c="red",label="mode")
plt.legend()
plt.show()

# %%
dataset.describe()
# Out:
#        Transaction ID          Day        Month         Year   Units Sold  \
# count     3835.000000  3835.000000  3835.000000  3835.000000  3835.000000
# mean      1918.000000    15.703781     6.527249  2022.765319     4.993481
# std       1107.213469     8.822771     3.452030     0.917401     2.581122
# min          1.000000     1.000000     1.000000  2021.000000     1.000000
# 25%        959.500000     8.000000     4.000000  2022.000000     3.000000
# 50%       1918.000000    16.000000     7.000000  2023.000000     5.000000
# 75%       2876.500000    23.000000    10.000000  2024.000000     7.000000
# max       3835.000000    31.000000    12.000000  2024.000000     9.000000
#
#        Price Per Unit  Customer Age  Customer Ratings
# count     3835.000000   3835.000000       3835.000000
# mean     40114.036816     38.098305          3.693090
# std      17310.488427     12.110622          1.325069
# min      10011.110000     18.000000          1.000000
# ...
